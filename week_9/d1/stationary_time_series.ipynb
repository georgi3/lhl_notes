# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller

# %%
series = pd.read_csv('./daily-total-female-births.csv')  # add to plot date on x axis index_col=0)

# %%
series.plot()
# Out:
# <AxesSubplot:>

# %%
non_stationary = pd.read_csv('airline-passengers.csv')

# %%
non_stationary.plot()
# Out:
# <AxesSubplot:>

# %%
series.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Births'}>]], dtype=object)

# %%
X = series.iloc[:, 1]
split = round(len(X) / 2)
X1, X2 = X[0:split], X[split:]
mean1, mean2 = X1.mean(), X2.mean()
var1, var2 = X1.var(), X2.var()
print('mean1=%f, mean2=%f' % (mean1, mean2))
print('variance1=%f, variance2=%f' % (var1, var2))
# Out:
# mean1=39.763736, mean2=44.185792
# variance1=49.485308, variance2=48.976281

# %%
non_stationary
# Out:
#        Month  Passengers
# 0    1949-01         112
# 1    1949-02         118
# 2    1949-03         132
# 3    1949-04         129
# 4    1949-05         121
# ..       ...         ...
# 139  1960-08         606
# 140  1960-09         508
# 141  1960-10         461
# 142  1960-11         390
# 143  1960-12         432
#
# [144 rows x 2 columns]

# %%
X = non_stationary.iloc[:, 1]
split = int(len(X) / 2)
X1, X2 = X[0:split], X[split:]
mean1, mean2 = X1.mean(), X2.mean()
var1, var2 = X1.var(), X2.var()
print('mean1=%f, mean2=%f' % (mean1, mean2))
print('variance1=%f, variance2=%f' % (var1, var2))
# Out:
# mean1=182.902778, mean2=377.694444
# variance1=2275.694640, variance2=7471.736307

# %%
non_stationary.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Passengers'}>]], dtype=object)

# %%
X = np.log(non_stationary.iloc[:, 1])

# %%
X.hist()
# Out:
# <AxesSubplot:>

# %%
X.plot()
# Out:
# <AxesSubplot:>

# %%
split = int(len(X) / 2)
X1, X2 = X[0:split], X[split:]
mean1, mean2 = X1.mean(), X2.mean()
var1, var2 = X1.var(), X2.var()
print('mean1=%f, mean2=%f' % (mean1, mean2))
print('variance1=%f, variance2=%f' % (var1, var2))
# Out:
# mean1=5.175146, mean2=5.909206
# variance1=0.069338, variance2=0.049958

# %%
series = pd.read_csv('daily-total-female-births.csv', header=0, index_col=0).squeeze('columns')
X = series.values
result = adfuller(X)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -4.808291
# p-value: 0.000052
# Critical Values:
# 	1%: -3.449
# 	5%: -2.870
# 	10%: -2.571

# %%
series = pd.read_csv('airline-passengers.csv', header=0, index_col=0).squeeze('columns')
X = series.values
result = adfuller(X)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: 0.815369
# p-value: 0.991880
# Critical Values:
# 	1%: -3.482
# 	5%: -2.884
# 	10%: -2.579

# %%
X = series.values
X = np.log(X)
result = adfuller(X)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -1.717017
# p-value: 0.422367
# 	1%: -3.482
# 	5%: -2.884
# 	10%: -2.579
